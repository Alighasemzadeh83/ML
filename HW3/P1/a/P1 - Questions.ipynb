# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name:  Ali Ghasemzadeh
# Student-ID: 401106339

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)


def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# -------------------------------- TODO -------------------------------------
# In this section, split the data into training and test datasets, using 60,000 samples for training and the remaining samples for testing.
x_train, x_test, y_train, y_test = train_test_split(x, y_new, train_size=60000, test_size=10000, random_state=41, stratify=y)
# -------------------------------- TODO -------------------------------------

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation
        self.epsilon = 1e-8
        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'tanh':
            self.activation = self.tanh
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        # -------------------------------- TODO -------------------------------------
        # Do the same for other activation functions
        elif activation == 'softmax':
            self.activation = self.softmax
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu
        # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}

    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, 0)
        else:
            return np.maximum(0, x)
        # -------------------------------- TODO -------------------------------------

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        
        # -------------------------------- TODO -------------------------------------
        tan = (np.exp(x) - np.exp(-x))/(np.exp(x) + np.exp(-x))
        if derivative:
            return 1 - tan**2 
        else:
            return tan
        # -------------------------------- TODO -------------------------------------

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # -------------------------------- TODO -------------------------------------
        sig = 1 / (1 + np.exp(-x))
        if derivative:
            return sig*(1 - sig)
        else:
            return sig
        # -------------------------------- TODO -------------------------------------

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        # -------------------------------- TODO -------------------------------------
        exp_x = np.exp(x - np.max(x, axis=0, keepdims=True))
        return exp_x / np.sum(exp_x, axis=0, keepdims=True)
        # -------------------------------- TODO -------------------------------------

    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha)
        else:
            return np.where(x > 0, x, alpha * x)
        # -------------------------------- TODO -------------------------------------

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------

    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------

    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params

    def feed_forward(self, x):
        self.cache["A0"] = x.T
        # -------------------------------- TODO -------------------------------------
        # Perform feedforward pass through each hidden layer, applying weights, biases, and activation function
        for i in range(1, self.num_layers + 1):
            W = self.params[f"W{i}"]
            b = self.params[f"b{i}"]
            A_last = self.cache[f"A{i-1}"]
            Z = np.dot(W, A_last) + b
            self.cache[f"A{i}"] = self.activation(Z) if i < self.num_layers else self.softmax(Z)
        # -------------------------------- TODO -------------------------------------

        return self.cache[f"A{self.num_layers}"]

    def back_propagate(self, y, output):
        current_batch_size = y.shape[0]
        grads = {}

        # -------------------------------- TODO -------------------------------------
        # Backpropagate gradients through Output layer and each hidden layers
        dZ = output - y.T
        grads[f"dW{self.num_layers}"] = np.dot(dZ, self.cache[f"A{self.num_layers-1}"].T) / current_batch_size
        grads[f"db{self.num_layers}"] = np.sum(dZ, axis=1, keepdims=True) / current_batch_size
        for i in range(self.num_layers - 1, 0, -1):
            W = self.params[f"W{i+1}"]
            A = self.cache[f"A{i}"]
            last_A = self.cache[f"A{i-1}"]
            dZ = np.dot(W.T, dZ) * self.activation(A, True)
            grads[f"dW{i}"] = np.dot(dZ, last_A.T) / current_batch_size
            grads[f"db{i}"] = np.sum(dZ, axis=1, keepdims=True) / current_batch_size
            
        # -------------------------------- TODO -------------------------------------
        self.grads = grads
        return self.grads

    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # -------------------------------- TODO -------------------------------------
        # Compute cross-entropy loss as the negative average log-likelihood of the correct labels
        m = y.shape[0]
        l = -np.mean(np.sum(y * np.log(output.T + self.epsilon), axis=1))
        # -------------------------------- TODO -------------------------------------
        return l

    def initialize_momemtum_optimizer(self):
        momemtum_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for momentum updates of weights and biases in each layer
            momemtum_opt[f"vW{i}"] = np.zeros_like(self.params[f"W{i}"])
            momemtum_opt[f"vb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return momemtum_opt

    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for first and second moment estimates of weights and biases in each layer
            adam_opt[f"mW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"vW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"mb{i}"] = np.zeros_like(self.params[f"b{i}"])
            adam_opt[f"vb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        if self.optimizer == "sgd":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for SGD
                self.params[key] -= l_rate * self.grads["d" + key]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "momentum":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Momentum
                if key.startswith("W") or key.startswith("b"):
                    self.momemtum_opt["v" + key] = beta * self.momemtum_opt["v" + key] + (1 - beta) * self.grads["d" + key]
                    self.params[key] -= l_rate * self.momemtum_opt["v" + key]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "adam":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Adam
                if key.startswith("W") or key.startswith("b"):
                    self.adam_opt[f"m{key}"] = beta1 * self.adam_opt[f"m{key}"] + (1 - beta1) * self.grads["d" + key]
                    self.adam_opt[f"v{key}"] = beta2 * self.adam_opt[f"v{key}"] + (1 - beta2) * (self.grads["d" + key] ** 2)
                    m_hat = self.adam_opt[f"m{key}"] / (1 - beta1 ** t)
                    v_hat = self.adam_opt[f"v{key}"] / (1 - beta2 ** t)
                    self.params[key] -= l_rate * m_hat / (np.sqrt(v_hat) + epsilon)
                # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code


    def accuracy(self, y, output):
        # -------------------------------- TODO -------------------------------------
        # Calculate accuracy by comparing the pred and truth matrices
        predictions = np.argmax(output, axis=0)
        true = np.argmax(y, axis=1)
        return np.mean(predictions == true)
        # -------------------------------- TODO -------------------------------------

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        # Train
        for i in range(self.epochs):
            # Shuffle
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                # Batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                # Forward
                output = self.feed_forward(x)
                # Backprop
                grad = self.back_propagate(y, output)
                # Optimize
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            # Evaluate performance
            # Training data
            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            # Test data
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')

    def evaluate(self, x_test, y_test):
        # Test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')
        return test_acc, test_loss

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
# Run your experiments here ...
x_train1, x_val, y_train1, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42, stratify=np.argmax(y_train, axis=1))

optimizers = ['sgd', 'momentum', 'adam']
activation_functions = ['relu', 'sigmoid', 'tanh', 'leaky_relu', 'selu', 'elu']
learning_rates = [0.01, 0.001]
layer_sizes = [784, 128, 64, 10]
num_epochs = 20
batch_size = 64

results = []

# Iterate over all combinations of optimizers, activations, and learning rates
for optimizer in optimizers:
    for activation in activation_functions:
        for lr in learning_rates:
            print(f"Trainging Optimizer: {optimizer}, Activation: {activation}, Learning Rate: {lr}")
            model = MLP(layer_sizes, activation=activation)
            
            model.train(x_train=x_train1, 
                y_train=y_train1, 
                x_val=x_val, 
                y_val=y_val, 
                epochs=num_epochs, 
                batch_size=batch_size, 
                optimizer=optimizer, 
                l_rate=lr
            )
            
            test_acc, test_loss = model.evaluate(x_test, y_test)
            results.append({
                "optimizer": optimizer,
                "activation": activation,
                "learning_rate": lr,
                "test_accuracy": test_acc,
                "test_loss": test_loss
            })
# Out:
# Trainging Optimizer: sgd, Activation: relu, Learning Rate: 0.01
# Epoch 1: 0.84s, train acc=0.86, train loss=0.56, validation acc=0.86, validation loss=0.57
# Epoch 2: 1.71s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.39
# Epoch 3: 2.58s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.34
# Epoch 4: 3.41s, train acc=0.92, train loss=0.30, validation acc=0.91, validation loss=0.31
# Epoch 5: 4.25s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.30
# Epoch 6: 5.10s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.28
# Epoch 7: 5.96s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.27
# Epoch 8: 6.82s, train acc=0.94, train loss=0.23, validation acc=0.93, validation loss=0.25
# Epoch 9: 7.67s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.24
# Epoch 10: 8.52s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.23
# Epoch 11: 9.38s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.21
# Epoch 12: 10.25s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.21
# Epoch 13: 11.08s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.20
# Epoch 14: 11.92s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.19
# Epoch 15: 12.90s, train acc=0.96, train loss=0.16, validation acc=0.95, validation loss=0.18
# Epoch 16: 13.77s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.18
# Epoch 17: 14.67s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 18: 15.57s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 19: 16.51s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
# Epoch 20: 17.44s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
#
# Test acc=0.96, Test loss=0.15
# Trainging Optimizer: sgd, Activation: relu, Learning Rate: 0.001
# Epoch 1: 0.88s, train acc=0.33, train loss=2.19, validation acc=0.32, validation loss=2.19
# Epoch 2: 1.77s, train acc=0.52, train loss=1.98, validation acc=0.52, validation loss=1.98
# Epoch 3: 2.65s, train acc=0.68, train loss=1.67, validation acc=0.68, validation loss=1.67
# Epoch 4: 3.93s, train acc=0.76, train loss=1.33, validation acc=0.76, validation loss=1.33
# Epoch 5: 5.38s, train acc=0.80, train loss=1.06, validation acc=0.80, validation loss=1.06
# Epoch 6: 6.82s, train acc=0.82, train loss=0.88, validation acc=0.81, validation loss=0.88
# Epoch 7: 8.26s, train acc=0.83, train loss=0.75, validation acc=0.83, validation loss=0.75
# Epoch 8: 9.66s, train acc=0.84, train loss=0.67, validation acc=0.84, validation loss=0.67
# Epoch 9: 11.09s, train acc=0.85, train loss=0.61, validation acc=0.85, validation loss=0.61
# Epoch 10: 12.52s, train acc=0.86, train loss=0.56, validation acc=0.86, validation loss=0.57
# Epoch 11: 13.99s, train acc=0.87, train loss=0.53, validation acc=0.86, validation loss=0.53
# Epoch 12: 15.41s, train acc=0.87, train loss=0.50, validation acc=0.87, validation loss=0.50
# Epoch 13: 16.83s, train acc=0.88, train loss=0.48, validation acc=0.87, validation loss=0.48
# Epoch 14: 18.24s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.46
# Epoch 15: 19.65s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.45
# Epoch 16: 21.06s, train acc=0.89, train loss=0.43, validation acc=0.88, validation loss=0.43
# Epoch 17: 22.52s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.42
# Epoch 18: 23.96s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.41
# Epoch 19: 25.37s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.40
# Epoch 20: 26.76s, train acc=0.90, train loss=0.39, validation acc=0.89, validation loss=0.39
#
# Test acc=0.90, Test loss=0.38
# Trainging Optimizer: sgd, Activation: sigmoid, Learning Rate: 0.01
# Epoch 1: 1.80s, train acc=0.21, train loss=2.26, validation acc=0.21, validation loss=2.26
# Epoch 2: 3.65s, train acc=0.33, train loss=2.20, validation acc=0.34, validation loss=2.20
# Epoch 3: 5.13s, train acc=0.50, train loss=2.10, validation acc=0.50, validation loss=2.10
# Epoch 4: 6.13s, train acc=0.50, train loss=1.91, validation acc=0.50, validation loss=1.91
# Epoch 5: 7.16s, train acc=0.56, train loss=1.65, validation acc=0.56, validation loss=1.65
# Epoch 6: 8.16s, train acc=0.61, train loss=1.43, validation acc=0.62, validation loss=1.43
# Epoch 7: 9.16s, train acc=0.67, train loss=1.26, validation acc=0.67, validation loss=1.26
# Epoch 8: 10.20s, train acc=0.71, train loss=1.11, validation acc=0.71, validation loss=1.10
# Epoch 9: 11.21s, train acc=0.74, train loss=0.97, validation acc=0.74, validation loss=0.97
# Epoch 10: 12.29s, train acc=0.77, train loss=0.87, validation acc=0.77, validation loss=0.86
# Epoch 11: 13.41s, train acc=0.79, train loss=0.79, validation acc=0.79, validation loss=0.78
# Epoch 12: 14.40s, train acc=0.80, train loss=0.72, validation acc=0.80, validation loss=0.72
# Epoch 13: 15.40s, train acc=0.81, train loss=0.67, validation acc=0.82, validation loss=0.68
# Epoch 14: 16.40s, train acc=0.83, train loss=0.64, validation acc=0.82, validation loss=0.64
# Epoch 15: 17.39s, train acc=0.83, train loss=0.60, validation acc=0.83, validation loss=0.61
# Epoch 16: 18.39s, train acc=0.84, train loss=0.57, validation acc=0.84, validation loss=0.58
# Epoch 17: 19.46s, train acc=0.85, train loss=0.55, validation acc=0.85, validation loss=0.55
# Epoch 18: 20.56s, train acc=0.85, train loss=0.53, validation acc=0.85, validation loss=0.53
# Epoch 19: 21.57s, train acc=0.86, train loss=0.51, validation acc=0.86, validation loss=0.52
# Epoch 20: 22.57s, train acc=0.86, train loss=0.49, validation acc=0.86, validation loss=0.50
#
# Test acc=0.86, Test loss=0.49
# Trainging Optimizer: sgd, Activation: sigmoid, Learning Rate: 0.001
# Epoch 1: 0.99s, train acc=0.11, train loss=2.31, validation acc=0.11, validation loss=2.31
# Epoch 2: 2.00s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 3: 3.04s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 4: 4.02s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 5: 5.03s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 6: 6.07s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 7: 7.10s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 8: 8.13s, train acc=0.14, train loss=2.27, validation acc=0.14, validation loss=2.27
# Epoch 9: 9.12s, train acc=0.14, train loss=2.27, validation acc=0.14, validation loss=2.27
# Epoch 10: 10.13s, train acc=0.17, train loss=2.26, validation acc=0.17, validation loss=2.26
# Epoch 11: 11.13s, train acc=0.19, train loss=2.26, validation acc=0.19, validation loss=2.26
# Epoch 12: 12.13s, train acc=0.21, train loss=2.26, validation acc=0.21, validation loss=2.26
# Epoch 13: 13.23s, train acc=0.23, train loss=2.25, validation acc=0.23, validation loss=2.25
# Epoch 14: 14.23s, train acc=0.25, train loss=2.25, validation acc=0.25, validation loss=2.25
# Epoch 15: 15.29s, train acc=0.28, train loss=2.24, validation acc=0.27, validation loss=2.24
# Epoch 16: 16.30s, train acc=0.33, train loss=2.24, validation acc=0.33, validation loss=2.24
# Epoch 17: 17.33s, train acc=0.32, train loss=2.23, validation acc=0.32, validation loss=2.23
# Epoch 18: 18.32s, train acc=0.33, train loss=2.23, validation acc=0.33, validation loss=2.23
# Epoch 19: 19.32s, train acc=0.35, train loss=2.22, validation acc=0.35, validation loss=2.22
# Epoch 20: 20.34s, train acc=0.39, train loss=2.21, validation acc=0.39, validation loss=2.21
#
# Test acc=0.38, Test loss=2.21
# Trainging Optimizer: sgd, Activation: tanh, Learning Rate: 0.01
# Epoch 1: 1.55s, train acc=0.87, train loss=0.54, validation acc=0.86, validation loss=0.55
# Epoch 2: 3.03s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.41
# Epoch 3: 4.46s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.36
# Epoch 4: 5.88s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.34
# Epoch 5: 7.37s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.32
# Epoch 6: 8.82s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.30
# Epoch 7: 10.32s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.29
# Epoch 8: 11.75s, train acc=0.92, train loss=0.26, validation acc=0.92, validation loss=0.28
# Epoch 9: 13.24s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.27
# Epoch 10: 14.77s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.27
# Epoch 11: 16.33s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.26
# Epoch 12: 17.90s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.25
# Epoch 13: 19.52s, train acc=0.94, train loss=0.23, validation acc=0.93, validation loss=0.25
# Epoch 14: 21.03s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.24
# Epoch 15: 22.54s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.24
# Epoch 16: 23.97s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.23
# Epoch 17: 25.45s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.23
# Epoch 18: 27.09s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.22
# Epoch 19: 28.58s, train acc=0.94, train loss=0.19, validation acc=0.94, validation loss=0.22
# Epoch 20: 30.04s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.21
#
# Test acc=0.94, Test loss=0.21
# Trainging Optimizer: sgd, Activation: tanh, Learning Rate: 0.001
# Epoch 1: 1.46s, train acc=0.63, train loss=1.69, validation acc=0.64, validation loss=1.69
# Epoch 2: 2.95s, train acc=0.73, train loss=1.29, validation acc=0.73, validation loss=1.29
# Epoch 3: 4.44s, train acc=0.78, train loss=1.05, validation acc=0.78, validation loss=1.05
# Epoch 4: 5.91s, train acc=0.81, train loss=0.90, validation acc=0.80, validation loss=0.90
# Epoch 5: 7.38s, train acc=0.83, train loss=0.80, validation acc=0.82, validation loss=0.80
# Epoch 6: 8.82s, train acc=0.84, train loss=0.72, validation acc=0.84, validation loss=0.72
# Epoch 7: 10.26s, train acc=0.85, train loss=0.66, validation acc=0.85, validation loss=0.67
# Epoch 8: 11.74s, train acc=0.86, train loss=0.62, validation acc=0.86, validation loss=0.62
# Epoch 9: 13.25s, train acc=0.86, train loss=0.58, validation acc=0.86, validation loss=0.59
# Epoch 10: 14.73s, train acc=0.87, train loss=0.55, validation acc=0.87, validation loss=0.56
# Epoch 11: 16.24s, train acc=0.87, train loss=0.53, validation acc=0.87, validation loss=0.53
# Epoch 12: 17.80s, train acc=0.88, train loss=0.50, validation acc=0.87, validation loss=0.51
# Epoch 13: 19.31s, train acc=0.88, train loss=0.49, validation acc=0.88, validation loss=0.49
# Epoch 14: 20.78s, train acc=0.88, train loss=0.47, validation acc=0.88, validation loss=0.48
# Epoch 15: 22.38s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.46
# Epoch 16: 23.82s, train acc=0.89, train loss=0.44, validation acc=0.88, validation loss=0.45
# Epoch 17: 25.33s, train acc=0.89, train loss=0.43, validation acc=0.88, validation loss=0.44
# Epoch 18: 26.79s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.43
# Epoch 19: 28.25s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.42
# Epoch 20: 29.75s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.41
#
# Test acc=0.90, Test loss=0.40
# Trainging Optimizer: sgd, Activation: leaky_relu, Learning Rate: 0.01
# Epoch 1: 0.86s, train acc=0.83, train loss=0.59, validation acc=0.83, validation loss=0.59
# Epoch 2: 1.72s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.32
# Epoch 3: 2.58s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.25
# Epoch 4: 3.45s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.22
# Epoch 5: 4.32s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.22
# Epoch 6: 5.19s, train acc=0.95, train loss=0.15, validation acc=0.95, validation loss=0.18
# Epoch 7: 6.07s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
# Epoch 8: 6.94s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
# Epoch 9: 7.82s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.15
# Epoch 10: 8.68s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.15
# Epoch 11: 9.56s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.14
# Epoch 12: 10.43s, train acc=0.96, train loss=0.11, validation acc=0.96, validation loss=0.14
# Epoch 13: 11.31s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.13
# Epoch 14: 12.19s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.13
# Epoch 15: 13.06s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.13
# Epoch 16: 13.94s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.13
# Epoch 17: 14.82s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.14
# Epoch 18: 15.70s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.13
# Epoch 19: 16.58s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 20: 17.55s, train acc=0.97, train loss=0.08, validation acc=0.96, validation loss=0.13
#
# Test acc=0.96, Test loss=0.13
# Trainging Optimizer: sgd, Activation: leaky_relu, Learning Rate: 0.001
# Epoch 1: 0.88s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 2: 1.74s, train acc=0.14, train loss=2.28, validation acc=0.14, validation loss=2.28
# Epoch 3: 2.67s, train acc=0.19, train loss=2.26, validation acc=0.19, validation loss=2.26
# Epoch 4: 3.68s, train acc=0.25, train loss=2.24, validation acc=0.25, validation loss=2.23
# Epoch 5: 4.71s, train acc=0.30, train loss=2.21, validation acc=0.30, validation loss=2.21
# Epoch 6: 5.59s, train acc=0.33, train loss=2.17, validation acc=0.34, validation loss=2.16
# Epoch 7: 6.49s, train acc=0.32, train loss=2.09, validation acc=0.33, validation loss=2.09
# Epoch 8: 7.36s, train acc=0.42, train loss=1.94, validation acc=0.42, validation loss=1.94
# Epoch 9: 8.25s, train acc=0.74, train loss=1.07, validation acc=0.75, validation loss=1.07
# Epoch 10: 9.13s, train acc=0.88, train loss=0.45, validation acc=0.87, validation loss=0.46
# Epoch 11: 10.06s, train acc=0.89, train loss=0.38, validation acc=0.89, validation loss=0.39
# Epoch 12: 10.96s, train acc=0.89, train loss=0.38, validation acc=0.88, validation loss=0.40
# Epoch 13: 11.85s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.36
# Epoch 14: 12.72s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.35
# Epoch 15: 13.59s, train acc=0.91, train loss=0.31, validation acc=0.91, validation loss=0.33
# Epoch 16: 14.59s, train acc=0.91, train loss=0.29, validation acc=0.91, validation loss=0.31
# Epoch 17: 15.63s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.31
# Epoch 18: 16.56s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.31
# Epoch 19: 17.51s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.30
# Epoch 20: 18.50s, train acc=0.92, train loss=0.26, validation acc=0.92, validation loss=0.28
#
# Test acc=0.92, Test loss=0.27
# Trainging Optimizer: sgd, Activation: selu, Learning Rate: 0.01
# Epoch 1: 1.18s, train acc=0.88, train loss=0.40, validation acc=0.88, validation loss=0.42
# Epoch 2: 2.49s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.28
# Epoch 3: 3.66s, train acc=0.92, train loss=0.24, validation acc=0.92, validation loss=0.26
# Epoch 4: 4.82s, train acc=0.93, train loss=0.22, validation acc=0.93, validation loss=0.24
# Epoch 5: 6.09s, train acc=0.94, train loss=0.19, validation acc=0.93, validation loss=0.21
# Epoch 6: 7.47s, train acc=0.94, train loss=0.18, validation acc=0.94, validation loss=0.21
# Epoch 7: 8.78s, train acc=0.91, train loss=0.27, validation acc=0.91, validation loss=0.30
# C:\Users\Ali\AppData\Local\Temp\ipykernel_20724\3179691498.py:138: RuntimeWarning: overflow encountered in exp
#   return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
# C:\Users\Ali\AppData\Local\Temp\ipykernel_20724\3179691498.py:138: RuntimeWarning: overflow encountered in multiply
#   return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
# C:\Users\Ali\AppData\Local\Temp\ipykernel_20724\3179691498.py:92: RuntimeWarning: invalid value encountered in subtract
#   exp_x = np.exp(x - np.max(x, axis=0, keepdims=True))
# Epoch 8: 9.85s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 9: 10.95s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 10: 12.04s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 11: 13.12s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 12: 14.29s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 13: 15.42s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 14: 16.47s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 15: 17.54s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 16: 18.58s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 17: 19.73s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 18: 20.80s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 19: 21.79s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 20: 22.78s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
#
# Test acc=0.10, Test loss=nan
# Trainging Optimizer: sgd, Activation: selu, Learning Rate: 0.001
# Epoch 1: 1.05s, train acc=0.19, train loss=2.24, validation acc=0.19, validation loss=2.24
# Epoch 2: 2.16s, train acc=0.27, train loss=2.11, validation acc=0.27, validation loss=2.11
# Epoch 3: 3.34s, train acc=0.35, train loss=1.93, validation acc=0.35, validation loss=1.93
# Epoch 4: 4.54s, train acc=0.67, train loss=1.10, validation acc=0.67, validation loss=1.10
# Epoch 5: 5.69s, train acc=0.87, train loss=0.43, validation acc=0.87, validation loss=0.45
# Epoch 6: 6.98s, train acc=0.89, train loss=0.39, validation acc=0.88, validation loss=0.41
# Epoch 7: 8.07s, train acc=0.89, train loss=0.37, validation acc=0.88, validation loss=0.40
# Epoch 8: 9.17s, train acc=0.90, train loss=0.33, validation acc=0.90, validation loss=0.36
# Epoch 9: 10.21s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.33
# Epoch 10: 11.26s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.32
# Epoch 11: 12.33s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.30
# Epoch 12: 13.42s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.29
# Epoch 13: 14.48s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.28
# Epoch 14: 15.59s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.27
# Epoch 15: 16.64s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.27
# Epoch 16: 17.72s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.25
# Epoch 17: 18.80s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.24
# Epoch 18: 19.87s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.24
# Epoch 19: 20.95s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.23
# Epoch 20: 22.01s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.23
#
# Test acc=0.94, Test loss=0.22
# Trainging Optimizer: sgd, Activation: elu, Learning Rate: 0.01
# Epoch 1: 1.06s, train acc=0.82, train loss=0.53, validation acc=0.82, validation loss=0.54
# Epoch 2: 2.12s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.34
# Epoch 3: 3.17s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.29
# Epoch 4: 4.19s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.23
# Epoch 5: 5.22s, train acc=0.93, train loss=0.22, validation acc=0.93, validation loss=0.24
# Epoch 6: 6.23s, train acc=0.94, train loss=0.18, validation acc=0.94, validation loss=0.20
# Epoch 7: 7.24s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.18
# Epoch 8: 8.31s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 9: 9.60s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.16
# Epoch 10: 10.67s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 11: 11.74s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
# Epoch 12: 12.89s, train acc=0.95, train loss=0.14, validation acc=0.94, validation loss=0.18
# Epoch 13: 13.95s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 14: 15.04s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 15: 16.14s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.19
# Epoch 16: 17.24s, train acc=0.96, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 17: 18.27s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 18: 19.33s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.15
# Epoch 19: 20.37s, train acc=0.97, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 20: 21.46s, train acc=0.96, train loss=0.11, validation acc=0.95, validation loss=0.17
#
# Test acc=0.95, Test loss=0.17
# Trainging Optimizer: sgd, Activation: elu, Learning Rate: 0.001
# Epoch 1: 1.01s, train acc=0.14, train loss=2.28, validation acc=0.13, validation loss=2.28
# Epoch 2: 2.02s, train acc=0.19, train loss=2.20, validation acc=0.19, validation loss=2.20
# Epoch 3: 3.05s, train acc=0.22, train loss=2.10, validation acc=0.23, validation loss=2.10
# Epoch 4: 4.06s, train acc=0.33, train loss=1.87, validation acc=0.33, validation loss=1.86
# Epoch 5: 5.08s, train acc=0.72, train loss=0.92, validation acc=0.72, validation loss=0.92
# Epoch 6: 6.14s, train acc=0.84, train loss=0.56, validation acc=0.83, validation loss=0.57
# Epoch 7: 7.18s, train acc=0.87, train loss=0.44, validation acc=0.87, validation loss=0.46
# Epoch 8: 8.21s, train acc=0.89, train loss=0.37, validation acc=0.89, validation loss=0.39
# Epoch 9: 9.26s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.36
# Epoch 10: 10.27s, train acc=0.89, train loss=0.35, validation acc=0.89, validation loss=0.37
# Epoch 11: 11.31s, train acc=0.89, train loss=0.35, validation acc=0.89, validation loss=0.37
# Epoch 12: 12.40s, train acc=0.90, train loss=0.34, validation acc=0.89, validation loss=0.35
# Epoch 13: 13.51s, train acc=0.91, train loss=0.29, validation acc=0.91, validation loss=0.31
# Epoch 14: 14.67s, train acc=0.91, train loss=0.29, validation acc=0.91, validation loss=0.31
# Epoch 15: 15.77s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.28
# Epoch 16: 16.95s, train acc=0.92, train loss=0.25, validation acc=0.92, validation loss=0.27
# Epoch 17: 18.16s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.26
# Epoch 18: 19.30s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.25
# Epoch 19: 20.43s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.25
# Epoch 20: 21.51s, train acc=0.93, train loss=0.23, validation acc=0.92, validation loss=0.25
#
# Test acc=0.93, Test loss=0.24
# Trainging Optimizer: momentum, Activation: relu, Learning Rate: 0.01
# Epoch 1: 1.12s, train acc=0.85, train loss=0.56, validation acc=0.85, validation loss=0.57
# Epoch 2: 2.20s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.40
# Epoch 3: 3.31s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.34
# Epoch 4: 4.96s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.31
# Epoch 5: 6.61s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.29
# Epoch 6: 8.34s, train acc=0.92, train loss=0.26, validation acc=0.92, validation loss=0.28
# Epoch 7: 10.01s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.26
# Epoch 8: 11.75s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.25
# Epoch 9: 13.46s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.23
# Epoch 10: 15.17s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.23
# Epoch 11: 16.93s, train acc=0.94, train loss=0.19, validation acc=0.94, validation loss=0.22
# Epoch 12: 18.31s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.21
# Epoch 13: 19.36s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.20
# Epoch 14: 20.47s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.19
# Epoch 15: 21.56s, train acc=0.96, train loss=0.16, validation acc=0.95, validation loss=0.18
# Epoch 16: 22.70s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.18
# Epoch 17: 23.83s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 18: 24.96s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 19: 26.09s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
# Epoch 20: 27.23s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
#
# Test acc=0.95, Test loss=0.15
# Trainging Optimizer: momentum, Activation: relu, Learning Rate: 0.001
# Epoch 1: 1.10s, train acc=0.40, train loss=2.14, validation acc=0.41, validation loss=2.14
# Epoch 2: 2.15s, train acc=0.60, train loss=1.90, validation acc=0.59, validation loss=1.90
# Epoch 3: 3.22s, train acc=0.68, train loss=1.59, validation acc=0.68, validation loss=1.59
# Epoch 4: 4.31s, train acc=0.74, train loss=1.28, validation acc=0.75, validation loss=1.28
# Epoch 5: 5.39s, train acc=0.78, train loss=1.03, validation acc=0.78, validation loss=1.03
# Epoch 6: 6.48s, train acc=0.81, train loss=0.86, validation acc=0.81, validation loss=0.86
# Epoch 7: 7.55s, train acc=0.83, train loss=0.74, validation acc=0.83, validation loss=0.74
# Epoch 8: 8.60s, train acc=0.84, train loss=0.66, validation acc=0.84, validation loss=0.66
# Epoch 9: 9.66s, train acc=0.85, train loss=0.60, validation acc=0.85, validation loss=0.60
# Epoch 10: 10.72s, train acc=0.86, train loss=0.55, validation acc=0.86, validation loss=0.56
# Epoch 11: 11.79s, train acc=0.87, train loss=0.52, validation acc=0.86, validation loss=0.52
# Epoch 12: 12.86s, train acc=0.87, train loss=0.49, validation acc=0.87, validation loss=0.49
# Epoch 13: 13.93s, train acc=0.88, train loss=0.47, validation acc=0.87, validation loss=0.47
# Epoch 14: 15.00s, train acc=0.88, train loss=0.45, validation acc=0.88, validation loss=0.45
# Epoch 15: 16.07s, train acc=0.88, train loss=0.43, validation acc=0.88, validation loss=0.44
# Epoch 16: 17.15s, train acc=0.89, train loss=0.42, validation acc=0.88, validation loss=0.42
# Epoch 17: 18.21s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.41
# Epoch 18: 19.29s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.40
# Epoch 19: 20.36s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.39
# Epoch 20: 21.43s, train acc=0.90, train loss=0.38, validation acc=0.89, validation loss=0.39
#
# Test acc=0.90, Test loss=0.37
# Trainging Optimizer: momentum, Activation: sigmoid, Learning Rate: 0.01
# Epoch 1: 1.21s, train acc=0.31, train loss=2.27, validation acc=0.30, validation loss=2.27
# Epoch 2: 2.42s, train acc=0.33, train loss=2.23, validation acc=0.33, validation loss=2.23
# Epoch 3: 3.70s, train acc=0.54, train loss=2.15, validation acc=0.54, validation loss=2.15
# Epoch 4: 4.97s, train acc=0.58, train loss=2.02, validation acc=0.58, validation loss=2.01
# Epoch 5: 6.23s, train acc=0.55, train loss=1.78, validation acc=0.55, validation loss=1.78
# Epoch 6: 7.47s, train acc=0.62, train loss=1.51, validation acc=0.63, validation loss=1.51
# Epoch 7: 8.74s, train acc=0.69, train loss=1.29, validation acc=0.69, validation loss=1.29
# Epoch 8: 9.97s, train acc=0.70, train loss=1.11, validation acc=0.70, validation loss=1.11
# Epoch 9: 11.20s, train acc=0.74, train loss=0.99, validation acc=0.74, validation loss=0.99
# Epoch 10: 12.42s, train acc=0.76, train loss=0.89, validation acc=0.76, validation loss=0.89
# Epoch 11: 13.64s, train acc=0.78, train loss=0.81, validation acc=0.78, validation loss=0.81
# Epoch 12: 14.87s, train acc=0.80, train loss=0.75, validation acc=0.80, validation loss=0.75
# Epoch 13: 16.11s, train acc=0.81, train loss=0.70, validation acc=0.81, validation loss=0.70
# Epoch 14: 17.36s, train acc=0.82, train loss=0.65, validation acc=0.82, validation loss=0.66
# Epoch 15: 18.66s, train acc=0.83, train loss=0.62, validation acc=0.83, validation loss=0.62
# Epoch 16: 19.93s, train acc=0.84, train loss=0.59, validation acc=0.84, validation loss=0.59
# Epoch 17: 21.16s, train acc=0.85, train loss=0.56, validation acc=0.84, validation loss=0.57
# Epoch 18: 22.41s, train acc=0.85, train loss=0.54, validation acc=0.85, validation loss=0.54
# Epoch 19: 23.67s, train acc=0.86, train loss=0.52, validation acc=0.85, validation loss=0.52
# Epoch 20: 24.93s, train acc=0.86, train loss=0.50, validation acc=0.86, validation loss=0.51
#
# Test acc=0.86, Test loss=0.50
# Trainging Optimizer: momentum, Activation: sigmoid, Learning Rate: 0.001
# Epoch 1: 1.22s, train acc=0.17, train loss=2.30, validation acc=0.17, validation loss=2.30
# Epoch 2: 2.48s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 3: 3.72s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 4: 4.95s, train acc=0.12, train loss=2.29, validation acc=0.12, validation loss=2.29
# Epoch 5: 6.20s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 6: 7.45s, train acc=0.14, train loss=2.28, validation acc=0.15, validation loss=2.28
# Epoch 7: 8.70s, train acc=0.14, train loss=2.28, validation acc=0.14, validation loss=2.28
# Epoch 8: 9.96s, train acc=0.17, train loss=2.27, validation acc=0.17, validation loss=2.27
# Epoch 9: 11.22s, train acc=0.18, train loss=2.27, validation acc=0.18, validation loss=2.27
# Epoch 10: 12.50s, train acc=0.20, train loss=2.26, validation acc=0.21, validation loss=2.26
# Epoch 11: 13.73s, train acc=0.22, train loss=2.26, validation acc=0.22, validation loss=2.26
# Epoch 12: 14.93s, train acc=0.24, train loss=2.26, validation acc=0.25, validation loss=2.26
# Epoch 13: 16.16s, train acc=0.26, train loss=2.25, validation acc=0.26, validation loss=2.25
# Epoch 14: 17.40s, train acc=0.27, train loss=2.25, validation acc=0.27, validation loss=2.25
# Epoch 15: 18.62s, train acc=0.29, train loss=2.24, validation acc=0.29, validation loss=2.24
# Epoch 16: 19.87s, train acc=0.32, train loss=2.24, validation acc=0.33, validation loss=2.24
# Epoch 17: 21.12s, train acc=0.37, train loss=2.23, validation acc=0.37, validation loss=2.23
# Epoch 18: 22.37s, train acc=0.37, train loss=2.23, validation acc=0.37, validation loss=2.23
# Epoch 19: 23.61s, train acc=0.39, train loss=2.22, validation acc=0.38, validation loss=2.22
# Epoch 20: 24.95s, train acc=0.38, train loss=2.21, validation acc=0.38, validation loss=2.21
#
# Test acc=0.38, Test loss=2.21
# Trainging Optimizer: momentum, Activation: tanh, Learning Rate: 0.01
# Epoch 1: 2.90s, train acc=0.87, train loss=0.56, validation acc=0.87, validation loss=0.56
# Epoch 2: 5.78s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.41
# Epoch 3: 8.69s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.36
# Epoch 4: 11.54s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.33
# Epoch 5: 14.42s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.31
# Epoch 6: 17.29s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.30
# Epoch 7: 19.52s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.29
# Epoch 8: 21.25s, train acc=0.92, train loss=0.26, validation acc=0.92, validation loss=0.28
# Epoch 9: 22.96s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.27
# Epoch 10: 24.70s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.26
# Epoch 11: 26.51s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.26
# Epoch 12: 28.21s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.25
# Epoch 13: 29.92s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.24
# Epoch 14: 31.63s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.24
# Epoch 15: 33.37s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.23
# Epoch 16: 35.09s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.23
# Epoch 17: 36.88s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.22
# Epoch 18: 38.58s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.22
# Epoch 19: 40.30s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.21
# Epoch 20: 42.03s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.21
#
# Test acc=0.94, Test loss=0.20
# Trainging Optimizer: momentum, Activation: tanh, Learning Rate: 0.001
# Epoch 1: 1.65s, train acc=0.64, train loss=1.73, validation acc=0.65, validation loss=1.73
# Epoch 2: 3.33s, train acc=0.75, train loss=1.34, validation acc=0.75, validation loss=1.34
# Epoch 3: 5.10s, train acc=0.79, train loss=1.09, validation acc=0.79, validation loss=1.09
# Epoch 4: 6.77s, train acc=0.81, train loss=0.93, validation acc=0.81, validation loss=0.93
# Epoch 5: 8.47s, train acc=0.83, train loss=0.81, validation acc=0.83, validation loss=0.81
# Epoch 6: 10.17s, train acc=0.84, train loss=0.73, validation acc=0.84, validation loss=0.73
# Epoch 7: 11.85s, train acc=0.85, train loss=0.67, validation acc=0.85, validation loss=0.67
# Epoch 8: 13.48s, train acc=0.86, train loss=0.62, validation acc=0.86, validation loss=0.62
# Epoch 9: 15.16s, train acc=0.86, train loss=0.58, validation acc=0.86, validation loss=0.59
# Epoch 10: 16.80s, train acc=0.87, train loss=0.55, validation acc=0.87, validation loss=0.55
# Epoch 11: 18.45s, train acc=0.87, train loss=0.53, validation acc=0.87, validation loss=0.53
# Epoch 12: 20.15s, train acc=0.88, train loss=0.50, validation acc=0.87, validation loss=0.51
# Epoch 13: 21.83s, train acc=0.88, train loss=0.49, validation acc=0.88, validation loss=0.49
# Epoch 14: 23.54s, train acc=0.88, train loss=0.47, validation acc=0.88, validation loss=0.47
# Epoch 15: 25.20s, train acc=0.88, train loss=0.45, validation acc=0.88, validation loss=0.46
# Epoch 16: 26.86s, train acc=0.89, train loss=0.44, validation acc=0.88, validation loss=0.45
# Epoch 17: 28.52s, train acc=0.89, train loss=0.43, validation acc=0.89, validation loss=0.44
# Epoch 18: 30.19s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.43
# Epoch 19: 31.84s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.42
# Epoch 20: 33.55s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.41
#
# Test acc=0.89, Test loss=0.40
# Trainging Optimizer: momentum, Activation: leaky_relu, Learning Rate: 0.01
# Epoch 1: 1.09s, train acc=0.87, train loss=0.44, validation acc=0.86, validation loss=0.46
# Epoch 2: 2.20s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.31
# Epoch 3: 3.34s, train acc=0.92, train loss=0.25, validation acc=0.92, validation loss=0.27
# Epoch 4: 4.44s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.23
# Epoch 5: 5.53s, train acc=0.94, train loss=0.18, validation acc=0.94, validation loss=0.20
# Epoch 6: 6.66s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.19
# Epoch 7: 7.78s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.17
# Epoch 8: 8.89s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 9: 10.01s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.19
# Epoch 10: 11.11s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 11: 12.21s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 12: 13.32s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 13: 14.42s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 14: 15.50s, train acc=0.97, train loss=0.10, validation acc=0.95, validation loss=0.15
# Epoch 15: 16.63s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.15
# Epoch 16: 17.72s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.18
# Epoch 17: 18.80s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.15
# Epoch 18: 19.89s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 19: 21.00s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.14
# Epoch 20: 22.08s, train acc=0.97, train loss=0.08, validation acc=0.96, validation loss=0.14
#
# Test acc=0.96, Test loss=0.13
# Trainging Optimizer: momentum, Activation: leaky_relu, Learning Rate: 0.001
# Epoch 1: 1.17s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 2: 2.32s, train acc=0.16, train loss=2.25, validation acc=0.17, validation loss=2.25
# Epoch 3: 3.50s, train acc=0.23, train loss=2.22, validation acc=0.24, validation loss=2.22
# Epoch 4: 4.71s, train acc=0.31, train loss=2.17, validation acc=0.31, validation loss=2.17
# Epoch 5: 5.89s, train acc=0.36, train loss=2.10, validation acc=0.36, validation loss=2.10
# Epoch 6: 7.10s, train acc=0.40, train loss=1.95, validation acc=0.41, validation loss=1.95
# Epoch 7: 8.28s, train acc=0.72, train loss=1.06, validation acc=0.72, validation loss=1.07
# Epoch 8: 9.38s, train acc=0.87, train loss=0.46, validation acc=0.86, validation loss=0.47
# Epoch 9: 10.51s, train acc=0.87, train loss=0.43, validation acc=0.87, validation loss=0.46
# Epoch 10: 11.61s, train acc=0.89, train loss=0.37, validation acc=0.89, validation loss=0.39
# Epoch 11: 12.70s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.35
# Epoch 12: 13.79s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.33
# Epoch 13: 14.90s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.35
# Epoch 14: 16.00s, train acc=0.91, train loss=0.30, validation acc=0.90, validation loss=0.33
# Epoch 15: 17.09s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.30
# Epoch 16: 18.19s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.29
# Epoch 17: 19.31s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.28
# Epoch 18: 20.41s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.29
# Epoch 19: 21.51s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.28
# Epoch 20: 22.60s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.28
#
# Test acc=0.92, Test loss=0.26
# Trainging Optimizer: momentum, Activation: selu, Learning Rate: 0.01
# Epoch 1: 1.29s, train acc=0.87, train loss=0.46, validation acc=0.86, validation loss=0.48
# Epoch 2: 2.60s, train acc=0.91, train loss=0.28, validation acc=0.91, validation loss=0.31
# Epoch 3: 3.90s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.26
# Epoch 4: 5.19s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.22
# Epoch 5: 6.45s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.20
# Epoch 6: 7.71s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.19
# Epoch 7: 8.98s, train acc=0.95, train loss=0.15, validation acc=0.95, validation loss=0.18
# Epoch 8: 10.32s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.19
# Epoch 9: 11.55s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 10: 12.78s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 11: 13.98s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 12: 15.17s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 13: 16.37s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 14: 17.59s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 15: 18.81s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 16: 20.05s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 17: 21.26s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 18: 22.46s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 19: 23.65s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
# Epoch 20: 24.88s, train acc=0.10, train loss=nan, validation acc=0.10, validation loss=nan
#
# Test acc=0.10, Test loss=nan
# Trainging Optimizer: momentum, Activation: selu, Learning Rate: 0.001
# Epoch 1: 1.28s, train acc=0.15, train loss=2.22, validation acc=0.15, validation loss=2.22
# Epoch 2: 2.58s, train acc=0.30, train loss=2.08, validation acc=0.30, validation loss=2.08
# Epoch 3: 3.84s, train acc=0.39, train loss=1.92, validation acc=0.39, validation loss=1.92
# Epoch 4: 5.10s, train acc=0.61, train loss=1.43, validation acc=0.61, validation loss=1.43
# Epoch 5: 6.37s, train acc=0.85, train loss=0.52, validation acc=0.84, validation loss=0.54
# Epoch 6: 7.67s, train acc=0.87, train loss=0.44, validation acc=0.86, validation loss=0.46
# Epoch 7: 8.96s, train acc=0.89, train loss=0.37, validation acc=0.89, validation loss=0.39
# Epoch 8: 10.25s, train acc=0.90, train loss=0.33, validation acc=0.90, validation loss=0.35
# Epoch 9: 11.52s, train acc=0.91, train loss=0.32, validation acc=0.90, validation loss=0.34
# Epoch 10: 12.79s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.32
# Epoch 11: 14.04s, train acc=0.91, train loss=0.31, validation acc=0.90, validation loss=0.33
# Epoch 12: 15.30s, train acc=0.92, train loss=0.30, validation acc=0.91, validation loss=0.32
# Epoch 13: 16.58s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.29
# Epoch 14: 17.86s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.28
# Epoch 15: 19.13s, train acc=0.92, train loss=0.25, validation acc=0.92, validation loss=0.28
# Epoch 16: 20.43s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.26
# Epoch 17: 21.70s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.26
# Epoch 18: 22.98s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.26
# Epoch 19: 24.25s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.24
# Epoch 20: 25.52s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.25
#
# Test acc=0.93, Test loss=0.23
# Trainging Optimizer: momentum, Activation: elu, Learning Rate: 0.01
# Epoch 1: 1.46s, train acc=0.85, train loss=0.51, validation acc=0.84, validation loss=0.52
# Epoch 2: 2.79s, train acc=0.90, train loss=0.32, validation acc=0.90, validation loss=0.34
# Epoch 3: 4.17s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.26
# Epoch 4: 5.46s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.23
# Epoch 5: 6.71s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.21
# Epoch 6: 7.99s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.19
# Epoch 7: 9.24s, train acc=0.95, train loss=0.15, validation acc=0.95, validation loss=0.18
# Epoch 8: 10.52s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 9: 11.77s, train acc=0.95, train loss=0.15, validation acc=0.95, validation loss=0.18
# Epoch 10: 13.01s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 11: 14.23s, train acc=0.95, train loss=0.15, validation acc=0.94, validation loss=0.19
# Epoch 12: 15.45s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 13: 16.67s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 14: 17.89s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.18
# Epoch 15: 19.11s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 16: 20.35s, train acc=0.96, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 17: 21.57s, train acc=0.96, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 18: 22.79s, train acc=0.97, train loss=0.10, validation acc=0.95, validation loss=0.15
# Epoch 19: 24.04s, train acc=0.97, train loss=0.10, validation acc=0.95, validation loss=0.15
# Epoch 20: 25.28s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.16
#
# Test acc=0.96, Test loss=0.15
# Trainging Optimizer: momentum, Activation: elu, Learning Rate: 0.001
# Epoch 1: 1.66s, train acc=0.15, train loss=2.24, validation acc=0.15, validation loss=2.24
# Epoch 2: 3.34s, train acc=0.19, train loss=2.18, validation acc=0.20, validation loss=2.17
# Epoch 3: 5.04s, train acc=0.26, train loss=2.10, validation acc=0.26, validation loss=2.10
# Epoch 4: 6.70s, train acc=0.28, train loss=2.02, validation acc=0.29, validation loss=2.02
# Epoch 5: 8.37s, train acc=0.39, train loss=1.87, validation acc=0.39, validation loss=1.87
# Epoch 6: 10.02s, train acc=0.65, train loss=1.31, validation acc=0.65, validation loss=1.30
# Epoch 7: 11.66s, train acc=0.85, train loss=0.51, validation acc=0.85, validation loss=0.52
# Epoch 8: 13.30s, train acc=0.89, train loss=0.41, validation acc=0.88, validation loss=0.43
# Epoch 9: 14.96s, train acc=0.90, train loss=0.33, validation acc=0.90, validation loss=0.35
# Epoch 10: 16.57s, train acc=0.91, train loss=0.33, validation acc=0.90, validation loss=0.35
# Epoch 11: 18.22s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.32
# Epoch 12: 19.85s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.31
# Epoch 13: 21.50s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.30
# Epoch 14: 23.15s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.29
# Epoch 15: 24.78s, train acc=0.92, train loss=0.27, validation acc=0.91, validation loss=0.29
# Epoch 16: 26.48s, train acc=0.92, train loss=0.26, validation acc=0.92, validation loss=0.29
# Epoch 17: 28.12s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.28
# Epoch 18: 29.79s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.27
# Epoch 19: 31.43s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.26
# Epoch 20: 33.10s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.26
#
# Test acc=0.93, Test loss=0.24
# Trainging Optimizer: adam, Activation: relu, Learning Rate: 0.01
# Epoch 1: 2.65s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.13
# Epoch 2: 5.39s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.11
# Epoch 3: 8.07s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 4: 10.73s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.12
# Epoch 5: 13.53s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 6: 16.39s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 7: 19.36s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.11
# Epoch 8: 22.19s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.12
# Epoch 9: 25.01s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.15
# ...
# Epoch 19: 41.28s, train acc=0.91, train loss=0.30, validation acc=0.91, validation loss=0.31
# Epoch 20: 43.35s, train acc=0.91, train loss=0.29, validation acc=0.91, validation loss=0.31
#
# Test acc=0.91, Test loss=0.30
# Trainging Optimizer: adam, Activation: tanh, Learning Rate: 0.01
# Epoch 1: 3.27s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.21
# Epoch 2: 6.22s, train acc=0.95, train loss=0.15, validation acc=0.94, validation loss=0.20
# Epoch 3: 8.88s, train acc=0.97, train loss=0.09, validation acc=0.95, validation loss=0.17
# Epoch 4: 11.44s, train acc=0.98, train loss=0.08, validation acc=0.95, validation loss=0.16
# Epoch 5: 13.98s, train acc=0.98, train loss=0.07, validation acc=0.95, validation loss=0.17
# Epoch 6: 16.18s, train acc=0.97, train loss=0.09, validation acc=0.95, validation loss=0.20
# Epoch 7: 18.30s, train acc=0.98, train loss=0.05, validation acc=0.95, validation loss=0.17
# Epoch 8: 20.58s, train acc=0.98, train loss=0.05, validation acc=0.95, validation loss=0.17
# Epoch 9: 22.73s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.16
# Epoch 10: 24.97s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.16
# Epoch 11: 27.18s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.16
# Epoch 12: 29.58s, train acc=0.99, train loss=0.04, validation acc=0.95, validation loss=0.20
# Epoch 13: 32.11s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.19
# Epoch 14: 34.72s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.18
# Epoch 15: 36.93s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.20
# Epoch 16: 39.17s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.19
# Epoch 17: 41.38s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.20
# Epoch 18: 43.64s, train acc=0.99, train loss=0.02, validation acc=0.96, validation loss=0.18
# Epoch 19: 46.05s, train acc=0.99, train loss=0.03, validation acc=0.96, validation loss=0.21
# Epoch 20: 48.37s, train acc=0.99, train loss=0.02, validation acc=0.96, validation loss=0.18
#
# Test acc=0.96, Test loss=0.18
# Trainging Optimizer: adam, Activation: tanh, Learning Rate: 0.001
# Epoch 1: 2.64s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.25
# Epoch 2: 5.22s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.21
# Epoch 3: 7.94s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.19
# Epoch 4: 10.87s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 5: 13.62s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 6: 16.54s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.15
# Epoch 7: 19.17s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.15
# Epoch 8: 21.81s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 9: 24.41s, train acc=0.98, train loss=0.08, validation acc=0.96, validation loss=0.14
# Epoch 10: 27.16s, train acc=0.98, train loss=0.07, validation acc=0.96, validation loss=0.13
# Epoch 11: 29.84s, train acc=0.98, train loss=0.06, validation acc=0.96, validation loss=0.13
# Epoch 12: 32.40s, train acc=0.99, train loss=0.05, validation acc=0.96, validation loss=0.12
# Epoch 13: 34.96s, train acc=0.99, train loss=0.05, validation acc=0.96, validation loss=0.12
# Epoch 14: 37.64s, train acc=0.99, train loss=0.04, validation acc=0.96, validation loss=0.12
# Epoch 15: 40.43s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 16: 43.01s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.12
# Epoch 17: 45.59s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.12
# Epoch 18: 48.21s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 19: 50.72s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 20: 53.30s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.11
#
# Test acc=0.97, Test loss=0.12
# Trainging Optimizer: adam, Activation: leaky_relu, Learning Rate: 0.01
# Epoch 1: 2.79s, train acc=0.60, train loss=5.03, validation acc=0.60, validation loss=5.04
# Epoch 2: 4.98s, train acc=0.61, train loss=5.21, validation acc=0.61, validation loss=5.21
# Epoch 3: 7.18s, train acc=0.68, train loss=4.31, validation acc=0.68, validation loss=4.36
# Epoch 4: 9.34s, train acc=0.65, train loss=4.70, validation acc=0.65, validation loss=4.73
# Epoch 5: 11.56s, train acc=0.62, train loss=5.90, validation acc=0.61, validation loss=6.01
# Epoch 6: 13.74s, train acc=0.73, train loss=4.28, validation acc=0.73, validation loss=4.31
# Epoch 7: 15.94s, train acc=0.70, train loss=5.05, validation acc=0.69, validation loss=5.17
# Epoch 8: 18.19s, train acc=0.69, train loss=5.24, validation acc=0.69, validation loss=5.28
# Epoch 9: 20.40s, train acc=0.73, train loss=4.70, validation acc=0.73, validation loss=4.74
# Epoch 10: 22.61s, train acc=0.82, train loss=3.06, validation acc=0.81, validation loss=3.21
# Epoch 11: 25.09s, train acc=0.71, train loss=4.76, validation acc=0.71, validation loss=4.86
# Epoch 12: 27.41s, train acc=0.64, train loss=6.22, validation acc=0.63, validation loss=6.30
# Epoch 13: 29.73s, train acc=0.70, train loss=5.19, validation acc=0.70, validation loss=5.23
# Epoch 14: 32.03s, train acc=0.84, train loss=2.75, validation acc=0.83, validation loss=2.80
# Epoch 15: 34.33s, train acc=0.72, train loss=4.80, validation acc=0.71, validation loss=4.94
# Epoch 16: 36.70s, train acc=0.81, train loss=3.34, validation acc=0.80, validation loss=3.43
# Epoch 17: 39.12s, train acc=0.72, train loss=4.82, validation acc=0.72, validation loss=4.94
# Epoch 18: 41.57s, train acc=0.59, train loss=7.39, validation acc=0.59, validation loss=7.40
# Epoch 19: 44.15s, train acc=0.70, train loss=5.26, validation acc=0.70, validation loss=5.34
# Epoch 20: 46.74s, train acc=0.71, train loss=5.15, validation acc=0.71, validation loss=5.15
#
# Test acc=0.72, Test loss=5.07
# Trainging Optimizer: adam, Activation: leaky_relu, Learning Rate: 0.001
# Epoch 1: 2.71s, train acc=0.93, train loss=0.26, validation acc=0.92, validation loss=0.28
# Epoch 2: 4.84s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.24
# Epoch 3: 6.71s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.24
# Epoch 4: 8.57s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.21
# Epoch 5: 10.45s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.21
# Epoch 6: 12.25s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.20
# Epoch 7: 14.21s, train acc=0.95, train loss=0.15, validation acc=0.95, validation loss=0.19
# Epoch 8: 16.02s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.18
# Epoch 9: 17.90s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.18
# Epoch 10: 19.72s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 11: 21.49s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.18
# Epoch 12: 23.27s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 13: 25.07s, train acc=0.96, train loss=0.12, validation acc=0.96, validation loss=0.16
# Epoch 14: 27.15s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 15: 28.98s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.15
# Epoch 16: 30.87s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.14
# Epoch 17: 32.66s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.14
# Epoch 18: 34.46s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.14
# Epoch 19: 36.24s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 20: 37.99s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.13
#
# Test acc=0.96, Test loss=0.14
# Trainging Optimizer: adam, Activation: selu, Learning Rate: 0.01
# Epoch 1: 2.39s, train acc=0.16, train loss=2.24, validation acc=0.16, validation loss=2.23
# Epoch 2: 4.88s, train acc=0.15, train loss=2.25, validation acc=0.15, validation loss=2.25
# Epoch 3: 7.56s, train acc=0.12, train loss=2.31, validation acc=0.12, validation loss=2.31
# Epoch 4: 10.43s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.27
# Epoch 5: 13.38s, train acc=0.14, train loss=2.25, validation acc=0.14, validation loss=2.26
# Epoch 6: 16.47s, train acc=0.14, train loss=2.29, validation acc=0.14, validation loss=2.29
# Epoch 7: 19.59s, train acc=0.16, train loss=2.26, validation acc=0.16, validation loss=2.27
# Epoch 8: 22.74s, train acc=0.15, train loss=2.21, validation acc=0.15, validation loss=2.21
# Epoch 9: 25.94s, train acc=0.13, train loss=2.27, validation acc=0.13, validation loss=2.27
# Epoch 10: 29.13s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 11: 32.42s, train acc=0.13, train loss=2.29, validation acc=0.13, validation loss=2.29
# Epoch 12: 35.84s, train acc=0.16, train loss=2.21, validation acc=0.16, validation loss=2.21
# Epoch 13: 39.13s, train acc=0.12, train loss=2.30, validation acc=0.12, validation loss=2.30
# Epoch 14: 42.55s, train acc=0.11, train loss=2.32, validation acc=0.11, validation loss=2.32
# Epoch 15: 45.87s, train acc=0.13, train loss=2.33, validation acc=0.13, validation loss=2.34
# Epoch 16: 49.13s, train acc=0.13, train loss=2.27, validation acc=0.13, validation loss=2.27
# Epoch 17: 52.44s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.29
# Epoch 18: 55.76s, train acc=0.13, train loss=2.25, validation acc=0.13, validation loss=2.25
# Epoch 19: 59.12s, train acc=0.10, train loss=2.32, validation acc=0.10, validation loss=2.31
# Epoch 20: 62.43s, train acc=0.17, train loss=2.18, validation acc=0.16, validation loss=2.18
#
# Test acc=0.17, Test loss=2.19
# Trainging Optimizer: adam, Activation: selu, Learning Rate: 0.001
# Epoch 1: 2.29s, train acc=0.90, train loss=0.33, validation acc=0.90, validation loss=0.35
# Epoch 2: 4.83s, train acc=0.92, train loss=0.28, validation acc=0.91, validation loss=0.31
# Epoch 3: 7.39s, train acc=0.93, train loss=0.25, validation acc=0.92, validation loss=0.27
# Epoch 4: 9.75s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.25
# Epoch 5: 11.98s, train acc=0.94, train loss=0.21, validation acc=0.93, validation loss=0.24
# Epoch 6: 14.30s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.22
# Epoch 7: 16.69s, train acc=0.94, train loss=0.20, validation acc=0.93, validation loss=0.22
# Epoch 8: 18.97s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.20
# Epoch 9: 21.25s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.19
# Epoch 10: 23.51s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.17
# Epoch 11: 25.77s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 12: 28.09s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 13: 30.45s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
# Epoch 14: 32.71s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 15: 35.03s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
# Epoch 16: 37.33s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 17: 39.64s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 18: 41.90s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
# Epoch 19: 44.19s, train acc=0.96, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 20: 46.52s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.17
#
# Test acc=0.96, Test loss=0.16
# Trainging Optimizer: adam, Activation: elu, Learning Rate: 0.01
# C:\Users\Ali\AppData\Local\Temp\ipykernel_20724\3179691498.py:123: RuntimeWarning: overflow encountered in exp
#   return np.where(x > 0, x, alpha * (np.exp(x) - 1))
# Epoch 1: 2.41s, train acc=0.10, train loss=2.41, validation acc=0.10, validation loss=2.41
# Epoch 2: 4.69s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.29
# Epoch 3: 7.04s, train acc=0.11, train loss=2.32, validation acc=0.11, validation loss=2.34
# Epoch 4: 9.54s, train acc=0.15, train loss=2.24, validation acc=0.14, validation loss=2.24
# Epoch 5: 12.15s, train acc=0.13, train loss=2.28, validation acc=0.13, validation loss=2.30
# Epoch 6: 14.94s, train acc=0.12, train loss=2.27, validation acc=0.12, validation loss=2.28
# Epoch 7: 18.21s, train acc=0.12, train loss=2.29, validation acc=0.12, validation loss=2.30
# Epoch 8: 21.18s, train acc=0.11, train loss=2.27, validation acc=0.11, validation loss=2.29
# Epoch 9: 24.34s, train acc=0.11, train loss=2.33, validation acc=0.11, validation loss=2.34
# Epoch 10: 27.46s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.29
# Epoch 11: 30.60s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.31
# Epoch 12: 33.78s, train acc=0.11, train loss=2.32, validation acc=0.11, validation loss=2.33
# Epoch 13: 37.05s, train acc=0.12, train loss=2.32, validation acc=0.12, validation loss=2.33
# Epoch 14: 40.27s, train acc=0.10, train loss=2.32, validation acc=0.10, validation loss=2.32
# Epoch 15: 43.44s, train acc=0.09, train loss=2.34, validation acc=0.09, validation loss=2.34
# Epoch 16: 46.63s, train acc=0.12, train loss=2.31, validation acc=0.12, validation loss=2.30
# Epoch 17: 49.83s, train acc=0.10, train loss=2.31, validation acc=0.10, validation loss=2.31
# Epoch 18: 53.03s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 19: 56.26s, train acc=0.12, train loss=2.30, validation acc=0.12, validation loss=2.30
# Epoch 20: 59.50s, train acc=0.11, train loss=2.31, validation acc=0.11, validation loss=2.32
#
# Test acc=0.10, Test loss=2.32
# Trainging Optimizer: adam, Activation: elu, Learning Rate: 0.001
# Epoch 1: 3.07s, train acc=0.92, train loss=0.29, validation acc=0.91, validation loss=0.31
# Epoch 2: 6.05s, train acc=0.93, train loss=0.24, validation acc=0.92, validation loss=0.27
# Epoch 3: 9.08s, train acc=0.94, train loss=0.19, validation acc=0.94, validation loss=0.22
# Epoch 4: 12.31s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.21
# Epoch 5: 15.60s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.21
# Epoch 6: 18.69s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.19
# Epoch 7: 21.72s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 8: 24.77s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 9: 27.89s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.17
# Epoch 10: 30.93s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
# Epoch 11: 34.00s, train acc=0.96, train loss=0.12, validation acc=0.95, validation loss=0.16
# Epoch 12: 37.14s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.16
# Epoch 13: 40.39s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.15
# Epoch 14: 43.46s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.15
# Epoch 15: 46.57s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.15
# Epoch 16: 49.63s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 17: 52.61s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 18: 55.67s, train acc=0.96, train loss=0.11, validation acc=0.95, validation loss=0.16
# Epoch 19: 58.71s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
# Epoch 20: 61.89s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.14
#
# Test acc=0.96, Test loss=0.14

# %%
# Find the best combination
best_result = max(results, key=lambda x: x['test_accuracy'])
print("\nBest configuration:")
print(f"Optimizer: {best_result['optimizer']}, Activation: {best_result['activation']}, "
      f"Learning Rate: {best_result['learning_rate']}")
print(f"Test Accuracy: {best_result['test_accuracy']:.2f}, Test Loss: {best_result['test_loss']:.2f}")
# Out:
# Best configuration:
# Optimizer: adam, Activation: relu, Learning Rate: 0.001
# Test Accuracy: 0.98, Test Loss: 0.10

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
def relu_approximation(input_data, target_labels):
    """
    Args:
      input_data: torch.tensor
        Input training data
      target_labels: torch.tensor
        Ground truth labels for training data

    Returns:
      activation_map: torch.tensor
        ReLU activations computed across the x-axis
      predicted_labels: torch.tensor
        Estimated labels or class predictions
        Derived from weighted sum of ReLU activations along the x-axis
      x_points: torch.tensor
        Points along the x-axis
    """
    ##############################---TODO---##############################
    # Number of ReLU units
    num_relus = input_data.shape[0] - 1

    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    # Compute bias for ReLU units
    biases = input_data[:, 0]

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros(num_relus, len(x_points))

    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])


    ## WEIGHTED SUM OF RELUS

    relu_weights = torch.zeros(num_relus)
    previous_slope = 0
    for j in range(num_relus):
      numerator = target_labels[j+1] - target_labels[j]
      denomerator = input_data[j+1] - input_data[j]
      slope = numerator / denomerator
      relu_weights[j] = slope - previous_slope
      previous_slope = slope

    # Compute predicted labels as weighted sum of ReLU activations
    predicted_labels = relu_weights @ activation_map
    ##############################---TODO---##############################

    return predicted_labels, activation_map, x_points


# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)

predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)
plot_function_apx(x_points, activation_map, predicted_output)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()

    activation_functions = {
            'relu': nn.ReLU(),
            'tanh': nn.Tanh(),
            'sigmoid': nn.Sigmoid(),
            'leaky_relu': nn.LeakyReLU(),
        }

    in_num = input_feature_num
    ##############################---TODO---##############################
    for i in range(len(hidden_unit_nums)):
      self.mlp.add_module(f'Hidden_Linear_{i}', nn.Linear(in_num, hidden_unit_nums[i]))
      self.mlp.add_module(f'Hidden_Activation_{i}', activation_functions[activation_fn])
      in_num = hidden_unit_nums[i]
    
    out_layer = nn.Linear(in_num, output_feature_num) # final layer
    self.mlp.add_module('Output_Linear', out_layer)

    ##############################---TODO---##############################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    # Reshape inputs to (batch_size, input_feature_num)
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x) # forward pass

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                        #  worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          # worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
# $$
# \begin{equation}
# \text{number of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
# $$
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ##############################---TODO---##############################
    terms_power = []
    for i in range(1, poly_degree + 1):
      for j in range(i+1):
        terms_power.append((i-j, j))
    
    num_features = len(terms_power)
    poly_X = torch.zeros((X.shape[0], num_features))
    
    for i, (j, k) in enumerate(terms_power):
      poly_X[:, i] = (X[:, 0]**j)*(X[:, 1]**k)

    return poly_X, num_features
    ##############################---TODO---##############################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                # worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                #  worker_init_fn=seed_worker,
                                 generator=g_seed)

  # Defining a linear model using MLP class
  poly_net = MLP_pytorch('ReLU()', num_features, [], K)

  # Train and test
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 70.03
# Accuracy on the 800 testing samples: 68.12
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?
#
# Deeper model with a hidden layer of 128 neurons have higher accuracy compared to wide network because deeper network can learn more complex functions and patterns and improving generalization
# in term decision boundaryies, the deeper model is smoother and have more stable boundary but wide network has Irregular boundaries because of overfitting
# wide network tries to fit to even small noises and it causes overfitting

# %%
##############################---TODO---##############################
seed_setter(SEED)
net2 = MLP_pytorch("relu", 2, [128], K)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-3)
num_epochs = 100

_, _ = train_test_classification(net2, criterion, optimizer, train_loader,
                                 test_loader, num_epochs=num_epochs,
                                 training_plot=True)

X_all = sample_grid()
y_pred = net2(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 97.81
# Accuracy on the 800 testing samples: 97.62
